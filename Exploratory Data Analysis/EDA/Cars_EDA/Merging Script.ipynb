# %%
import pandas as pd
import numpy as np

# %%
csv1 = pd.read_csv("9_tradeuniquecars.csv")

# %%
csv1
# Out:
#       Unnamed: 0       Make                 Model    Price    Year  \
# 0              0         AC                 COBRA  70000.0  1995.0
# 1              1     SUBARU            LIBERTY Gt  20000.0  1997.0
# 2              2     TOYOTA                 CAMRY  11500.0  2016.0
# 3              3       FORD     CORTINA TC 2 Door  57995.0  1972.0
# 4              4       FORD             FALCON XF  15000.0  1985.0
# ...          ...        ...                   ...      ...     ...
# 1040        1040  CHEVROLET                BELAIR      NaN  1957.0
# 1041        1041   PLYMOUTH   ROAD RUNNER TRIBUTE      NaN  1968.0
# 1042        1042         AC                 COBRA      NaN  2001.0
# 1043        1043        HSV               W427 VE      NaN  2009.0
# 1044        1044  CHEVROLET           CORVETTE C6      NaN  2008.0
#
#      Transmission Listing Type        Body Type         Fuel Type  \
# 0       Automatic         Used         Soft Top  Premium Unleaded
# ...

# %%
csv2 = pd.read_csv("10_duttonrage.csv")

# %%
csv2
# Out:
#     Unnamed: 0             Make  \
# 0            0          Porsche
# 1            1              BMW
# 2            2       Land Rover
# 3            3          Porsche
# 4            4          Porsche
# 5            5    Mercedes-Benz
# 6            6         Maserati
# 7            7              BMW
# 8            8          Ferrari
# 9            9          Porsche
# 10          10          Porsche
# 11          11    Mercedes-Benz
# 12          12            Lexus
# 13          13              BMW
# 14          14              BMW
# 15          15            Tesla
# 16          16    Mercedes-Benz
# 17          17      Lamborghini
# 18          18    Mercedes-Benz
# 19          19          Porsche
# 20          20    Mercedes-Benz
# 21          21              BMW
# 22          22  HARLEY DAVIDSON
# 23          23          McLaren
# 24          24            Mazda
# 25          25    Mercedes-Benz
# 26          26          Ferrari
# 27          27          Ferrari
# ...

# %%
csv1.drop(["Unnamed: 0"],axis=1,inplace=True)
csv2.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
import os
import glob
import pandas as pd
os.chdir("C:/Users/Dell/Downloads/EDA_Cars")

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
print(all_filenames)

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "cars_dataset.csv", index=False, encoding='utf-8-sig')
# Out:
# ['10_duttonrage.csv', '9_tradeuniquecars.csv']

# %%
merged = pd.read_csv("cars_dataset.csv")
merged.drop(["Unnamed: 0"],axis =1 , inplace=True)

# %%
pd.read_csv("cars_dataset.csv")
# Out:
#       Unnamed: 0        Make  \
# 0              0     Porsche
# 1              1         BMW
# 2              2  Land Rover
# 3              3     Porsche
# 4              4     Porsche
# ...          ...         ...
# 1094        1040   CHEVROLET
# 1095        1041    PLYMOUTH
# 1096        1042          AC
# 1097        1043         HSV
# 1098        1044   CHEVROLET
#
#                                                   Model       Price    Year  \
# 0      911 992 Carrera S Coupe 2dr PDK 8sp 3.0TT [MY21]         NaN  2020.0
# 1      i8 I12 LCI Coupe 2dr Auto 6sp AWD 1.5T/105kW ...         NaN  2019.0
# 2      Defender 90 Adventure Wagon 3dr Man 6sp 4x4 2...  10999000.0  2015.0
# 3      911 997 Series II Carrera Cabriolet 2dr PDK 7...         NaN  2009.0
# 4      Cayenne 9YB Turbo Coupe 5dr Tiptronic 8sp 4x4...         NaN  2020.0
# ...                                                 ...         ...     ...
# ...
