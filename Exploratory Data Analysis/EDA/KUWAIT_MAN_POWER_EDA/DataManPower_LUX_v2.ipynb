# %% [markdown]
# "Lux is built on the philosophy that users should always be able to visualize anything they want without having to think about how the visualization should look like".
#
# -- In Lux, you don’t explicitly create plots; you simply specify your analysis intent, i.e., what attributes/subset interest you; Lux takes care of the rest. Apart from this, Lux is tightly integrated with Pandas and can be used without modifying any code with just one import statement. It preserves the Pandas data frame semantics, so all the commands from the Pandas’s API work in Lux as expected.
#
# -- Lux is a python API for intelligent visual discovery, which comes with an inbuilt interactive jupyter widget.
#
# -- Lux could be your intelligent assistant which can automate the visual aspects of the exploratory data analysis.
#
# -- It provides powerful abstractions of the visualizations soon after the data frame has been displayed in the jupyter notebook with just a click.
#
# -- Lux is a very rich user intent-based language.
#
# -- The main intention of the Lux Library is,to make the visualizations as simple as loading a .
#
# -- The interactive Lux widget assists the user to quickly browse through the data and view important trends and patterns.
#
# -- It provides recommendations for the user to analyze further. Lux, can also create visualizations for those sections of the data, you have no clear idea about.

# %% [markdown]
# # Installing Libraries and Dependencies

# %%
#### Installation is needed to be done using terminal

# %%
#Install Lux from PyPI

# !pip install lux-api

# %%
#Install and activate the Lux notebook extension (lux-widget) included in the package.
jupyter nbextension install --py luxwidget
jupyter nbextension enable --py luxwidget

# %% [markdown]
# # Importing Libraries and Dependencies

# %%
import lux
import pandas as pd

# %% [markdown]
# # Reading Dataset

# %%
df = pd.read_spss('DataManPower.sav')
df = df[0:500]

# %%
#hide
df['BIRTH_DATE'] = pd.to_datetime(df['BIRTH_DATE'], errors = 'coerce')
df['BIRTH_DATE']
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
#hide
def from_dob_to_age(born):
    today = datetime.today()
    return (today - born).days / 365.25

# %%
#hide
from datetime import datetime
df['Age'] = df['BIRTH_DATE'].apply(lambda x: from_dob_to_age(x))
df['Age']
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df['Age'] = df['Age'].round(2)
df['Age']
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
#hide
df['CIVIL_ID'] = pd.to_numeric(df['CIVIL_ID'])
df['COUNTRY_CODE'] = pd.to_numeric(df['COUNTRY_CODE'])
df['GENDER_CODE'] = pd.to_numeric(df['GENDER_CODE'])
df['COUNTRY_CODE'] = pd.to_numeric(df['COUNTRY_CODE'])
df['RLGION_CODE'] = pd.to_numeric(df['RLGION_CODE'])
df['JOB_CODE'] = pd.to_numeric(df['JOB_CODE'])
df['ECONOMIC_ACT_CODE'] = pd.to_numeric(df['ECONOMIC_ACT_CODE'])
df['EDUCATION_CODE'] = pd.to_numeric(df['EDUCATION_CODE'])
df['MAJOR_CODE'] = pd.to_numeric(df['MAJOR_CODE'])
df['SALARY'] = pd.to_numeric(df['SALARY'])
df['SALARY_TYPE'] = pd.to_numeric(df['SALARY_TYPE'])
df['ONR_GVRN_CODE'] = pd.to_numeric(df['ONR_GVRN_CODE'])
df['MARITAL_STATUS_CODE'] = pd.to_numeric(df['MARITAL_STATUS_CODE'])
df['ADDRESS_AUTO_NO'] = pd.to_numeric(df['ADDRESS_AUTO_NO'])
df['ONR_ID'] = pd.to_numeric(df['ONR_ID'])
df['جنسية'] = pd.to_numeric(df['جنسية'])

#hide
from datetime import datetime
df['HIRE_DATE'] = pd.to_datetime(df['HIRE_DATE'], errors = 'coerce')
df['BIRTH_DATE'] = pd.to_datetime(df['BIRTH_DATE'],errors = 'coerce')

#hide
df['COUNTRY_DESC'] = df['COUNTRY_DESC'].astype('str')
df['GENDER_DESC'] = df['GENDER_DESC'].astype('str')
df['RLGION_DESC'] = df['RLGION_DESC'].astype('str')
df['JOB_DESC'] = df['JOB_DESC'].astype('str')
df['SECTOR'] = df['SECTOR'].astype('str')
df['ECONOMIC_ACT_DESC'] = df['ECONOMIC_ACT_DESC'].astype('str')
df['EDUCATION_DESC'] = df['EDUCATION_DESC'].astype('str')
df['GOVERNORATE_DESC'] = df['GOVERNORATE_DESC'].astype('str')
df['MARITAL_STATUS_DESC'] = df['MARITAL_STATUS_DESC'].astype('str')
df['COMPANY_NAME'] = df['COMPANY_NAME'].astype('str')

# %%
#after printing a data frame, a toggle option is facilitated to view the Lux visualizations

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# This creates several plots divided into three tabs:
#
# -- **Correlation:**
#
# Visualizes the relationships between two qualitative attributes.
#
# The plots are arranged from the highest to the lowest correlated pair of attributes.
#
# -- **Distribution:**
#
# Shows histogram distributions of different quantitative attributes, ranked from the most to least skewed.
#
# -- **Occurrence:**
#
# Displays bar chart distributions of different categorical attributes, ranked from most to least uneven plots.

# %% [markdown]
# # Intent

# %% [markdown]
# In addition to dataframe visualizations at every step in the exploration, attributes and values of interest can be specified in Lux.
#
# Based on this intent, Lux guides users towards potential next-steps in their exploration.

# %%
df.columns
# Out:
# Index(['CIVIL_ID', 'BIRTH_DATE', 'COUNTRY_CODE', 'COUNTRY_DESC', 'GENDER_CODE',
#        'GENDER_DESC', 'RLGION_CODE', 'RLGION_DESC', 'JOB_CODE', 'JOB_DESC',
#        'SECTOR', 'ECONOMIC_ACT_CODE', 'ECONOMIC_ACT_DESC', 'EDUCATION_CODE',
#        'EDUCATION_DESC', 'MAJOR_CODE', 'SALARY', 'SALARY_TYPE',
#        'ONR_GVRN_CODE', 'GOVERNORATE_DESC', 'MARITAL_STATUS_CODE',
#        'MARITAL_STATUS_DESC', 'COMPANY_NAME', 'HIRE_DATE', 'ADDRESS_AUTO_NO',
#        'ONR_ID', 'جنسية', 'Age'],
#       dtype='object')

# %%
df.intent = ["SALARY","JOB_CODE"]
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df["JOB_CODE"]
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df[df["JOB_CODE"]==21930].to_pandas()
# Out:
#          CIVIL_ID BIRTH_DATE  COUNTRY_CODE COUNTRY_DESC  GENDER_CODE  \
# 48   279100200406 1979-01-01         101.0       الكويت            2
# 117  272051201434 1972-01-01         721.0      باكستان            1
# 498  262122800233 1962-01-01         106.0       الأردن            1
#
#     GENDER_DESC  RLGION_CODE RLGION_DESC  JOB_CODE     JOB_DESC  ...  \
# 48         انثى          NaN                 21930  مدير مبيعات  ...
# 117         ذكر          1.0        مسلم     21930  مدير مبيعات  ...
# 498         ذكر          1.0        مسلم     21930  مدير مبيعات  ...
#
#     ONR_GVRN_CODE  GOVERNORATE_DESC MARITAL_STATUS_CODE  MARITAL_STATUS_DESC  \
# 48              5  محافظة الفروانية                   2                متزوج
# 117             1    محافظة العاصمة                   2                متزوج
# 498             1    محافظة العاصمة                   2                متزوج
#
#                                           COMPANY_NAME  HIRE_DATE  \
# 48   مصنع نسيم الكويت لتصنيع الزجاج المشغول والمراي... 2020-04-01
# 117               المشاعل لصياغة الحلى الذهبية والفضية 2008-12-16
# 498  شركة الانارة العالمية لبيع الادوات الكهربائية ... 2010-02-21
#
#      ADDRESS_AUTO_NO        ONR_ID  جنسية    Age
# 48          13161911  2.934360e+11    1.0  42.40
# 117         10051709  2.500427e+11    2.0  49.40
# 498         10527279  2.829997e+11    2.0  59.39
#
# [3 rows x 28 columns]

# %%
df[df["JOB_CODE"]==32125].to_pandas()
# Out:
# Empty DataFrame
# Columns: [CIVIL_ID, BIRTH_DATE, COUNTRY_CODE, COUNTRY_DESC, GENDER_CODE, GENDER_DESC, RLGION_CODE, RLGION_DESC, JOB_CODE, JOB_DESC, SECTOR, ECONOMIC_ACT_CODE, ECONOMIC_ACT_DESC, EDUCATION_CODE, EDUCATION_DESC, MAJOR_CODE, SALARY, SALARY_TYPE, ONR_GVRN_CODE, GOVERNORATE_DESC, MARITAL_STATUS_CODE, MARITAL_STATUS_DESC, COMPANY_NAME, HIRE_DATE, ADDRESS_AUTO_NO, ONR_ID, جنسية, Age]
# Index: []
#
# [0 rows x 28 columns]

# %%
df = df[(df["JOB_CODE"]!=43390) & (df["JOB_CODE"]!=21930)]
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# The left-hand side of the widget shows the current visualization, i.e. the current visualization generated based on what the user is interested in. On the right, Lux generates three sets of recommendations, organized as separate tabs on the widget:
#
# Enhance adds an additional attribute to the current selection, essentially highlighting how additional variables affect the relationship of Job DESC and SALARY.

# %% [markdown]
# **Filter** adds a filter to the current selection, while keeping attributes (on the X and Y axes) fixed. These visualizations shows how the relationship of JOB DESC and SALARY changes for different subsets of data.

# %% [markdown]
# **Generalize** removes an attribute to display a more general trend, showing the distributions of AverageCost and SATAverage on its own

# %% [markdown]
# # Vis

# %% [markdown]
# Visualizations are represented as Vis objects in Lux. These Vis objects can be translated into Altair or VegaLite code

# %% [markdown]
# ux is built on the philosophy that users should always be able to visualize anything they want, without having to think about how the visualization should look like. Lux automatically determines the mark and channel mappings based on a set of best practices from Tableau. The visualizations are rendered via Altair into Vega-Lite specifications.

# %%
from lux.vis.Vis import Vis
job_salary = Vis(["JOB_CODE","SALARY"],df)
job_salary
# Out:
# LuxWidget(current_vis={'config': {'view': {'continuousWidth': 400, 'continuousHeight': 300}, 'axis': {'labelCo…

# %% [markdown]
# # Vis List

# %% [markdown]
# we can create a set of visualizations of Weight with respect to all other attributes, using the wildcard “?” symbol

# %%
from lux.vis.VisList import VisList
VisList(["GENDER_CODE","?"],df)
# Out:
# LuxWidget(recommendations=[{'action': 'Vis List', 'description': 'Shows a vis list defined by the intent', 'vs…

# %%
VisList(["ONR_GVRN_CODE","?"],df)
# Out:
# LuxWidget(recommendations=[{'action': 'Vis List', 'description': 'Shows a vis list defined by the intent', 'vs…

# %% [markdown]
# # Recommendation

# %% [markdown]
# We can also access the set of recommendations generated for the data frames via the properties recommendation. The output is a dictionary, keyed by the name of the recommendation category.

# %%
df.recommendation
# Out:
# {'Enhance': [<Vis  (x: SALARY, y: JOB_CODE, color: SECTOR) mark: scatter, score: 1.00 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: SALARY_TYPE) mark: scatter, score: 1.00 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: جنسية) mark: scatter, score: 0.50 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: GENDER_CODE) mark: scatter, score: 0.50 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: GENDER_DESC) mark: scatter, score: 0.50 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: MARITAL_STATUS_CODE) mark: scatter, score: 0.25 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: MARITAL_STATUS_DESC) mark: scatter, score: 0.25 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: RLGION_CODE) mark: scatter, score: 0.20 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: RLGION_DESC) mark: scatter, score: 0.20 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: ONR_GVRN_CODE) mark: scatter, score: 0.17 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: GOVERNORATE_DESC) mark: scatter, score: 0.17 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: EDUCATION_DESC) mark: scatter, score: 0.12 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: EDUCATION_CODE) mark: scatter, score: 0.11 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: MAJOR_CODE) mark: scatter, score: 0.10 >,
#   <Vis  (x: SALARY, y: JOB_CODE, color: ONR_ID) mark: scatter, score: 0.10 >],
#  'Filter': [<Vis  (x: SALARY, y: JOB_CODE  -- [COUNTRY_CODE=721.0]           ) mark: scatter, score: 0.73 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [COUNTRY_DESC=باكستان]         ) mark: scatter, score: 0.73 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [MAJOR_CODE=55.0]              ) mark: scatter, score: 0.72 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [COUNTRY_CODE=110.0]           ) mark: scatter, score: 0.68 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [COUNTRY_DESC=ســوريا]         ) mark: scatter, score: 0.68 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [MAJOR_CODE=554000.0]          ) mark: scatter, score: 0.62 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [ONR_GVRN_CODE=2]              ) mark: scatter, score: 0.57 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [GOVERNORATE_DESC=محافظة حولي] ) mark: scatter, score: 0.57 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [COUNTRY_CODE=720.0]           ) mark: scatter, score: 0.54 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [COUNTRY_DESC=نيبال]           ) mark: scatter, score: 0.54 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [EDUCATION_CODE=55.0]          ) mark: scatter, score: 0.54 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [EDUCATION_DESC=ابتدائي]       ) mark: scatter, score: 0.54 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [EDUCATION_DESC=جامعى]         ) mark: scatter, score: 0.50 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [MARITAL_STATUS_CODE=1]        ) mark: scatter, score: 0.49 >,
#   <Vis  (x: SALARY, y: JOB_CODE  -- [MARITAL_STATUS_DESC=أعزب]     ) mark: scatter, score: 0.49 >],
#  'Generalize': [<Vis  (x: BIN(SALARY)  , y: COUNT(Record)) mark: histogram, score: 1.00 >,
#   <Vis  (x: BIN(JOB_CODE), y: COUNT(Record)) mark: histogram, score: 1.00 >]}

# %% [markdown]
# # Exporting Visualizations as Code

# %%
vis = df.recommendation["Enhance"][1]
vis
# Out:
# LuxWidget(current_vis={'config': {'view': {'continuousWidth': 400, 'continuousHeight': 300}, 'axis': {'labelCo…

# %%
print(vis.to_altair())
# Out:
# import altair as alt
#
# chart = alt.Chart(df).mark_circle().encode(
#     x=alt.X('SALARY',scale=alt.Scale(domain=(60, 5000)),type='quantitative', axis=alt.Axis(title='SALARY')),
#     y=alt.Y('JOB_CODE',scale=alt.Scale(domain=(2120, 99982)),type='quantitative', axis=alt.Axis(title='JOB_CODE'))
# )
# chart = chart.configure_mark(tooltip=alt.TooltipContent('encoding')) # Setting tooltip as non-null
# chart = chart.interactive() # Enable Zooming and Panning
# chart = chart.encode(color=alt.Color('SALARY_TYPE',type='nominal'))
#
# chart = chart.configure_title(fontWeight=500,fontSize=13,font='Helvetica Neue')
# chart = chart.configure_axis(titleFontWeight=500,titleFontSize=11,titleFont='Helvetica Neue',
# 			labelFontWeight=400,labelFontSize=8,labelFont='Helvetica Neue',labelColor='#505050')
# chart = chart.configure_legend(titleFontWeight=500,titleFontSize=10,titleFont='Helvetica Neue',
# 			labelFontWeight=400,labelFontSize=8,labelFont='Helvetica Neue')
# chart = chart.properties(width=160,height=150)
#
# chart

# %%
import altair as alt

chart = alt.Chart(df).mark_circle().encode(
    x=alt.X('SALARY',scale=alt.Scale(domain=(60, 5000)),type='quantitative', axis=alt.Axis(title='SALARY')),
    y=alt.Y('JOB_CODE',scale=alt.Scale(domain=(2120, 99982)),type='quantitative', axis=alt.Axis(title='JOB_CODE'))
)
chart = chart.configure_mark(tooltip=alt.TooltipContent('encoding')) # Setting tooltip as non-null
chart = chart.interactive() # Enable Zooming and Panning
chart = chart.encode(color=alt.Color('SALARY_TYPE',type='nominal'))

chart = chart.configure_title(fontWeight=500,fontSize=13,font='Helvetica Neue')
chart = chart.configure_axis(titleFontWeight=500,titleFontSize=11,titleFont='Helvetica Neue',
			labelFontWeight=400,labelFontSize=8,labelFont='Helvetica Neue',labelColor='#505050')
chart = chart.configure_legend(titleFontWeight=500,titleFontSize=10,titleFont='Helvetica Neue',
			labelFontWeight=400,labelFontSize=8,labelFont='Helvetica Neue')
chart = chart.properties(width=160,height=150)

chart
# Out:
# alt.Chart(...)

# %%
print(vis.to_vegalite())
# Out:
# ** Remove this comment -- Copy Text Below to Vega Editor(vega.github.io/editor) to visualize and edit **
# {
#   "config": {
#     "view": {
#       "continuousWidth": 400,
#       "continuousHeight": 300
#     },
#     "axis": {
#       "labelColor": "#505050",
#       "labelFont": "Helvetica Neue",
#       "labelFontSize": 9,
#       "labelFontWeight": 400,
#       "titleFont": "Helvetica Neue",
#       "titleFontSize": 11,
#       "titleFontWeight": 500
#     },
#     "legend": {
#       "labelFont": "Helvetica Neue",
#       "labelFontSize": 9,
#       "labelFontWeight": 400,
#       "titleFont": "Helvetica Neue",
#       "titleFontSize": 10,
#       "titleFontWeight": 500
#     },
#     "mark": {
#       "tooltip": {
#         "content": "encoding"
#       }
#     },
#     "title": {
#       "font": "Helvetica Neue",
#       "fontSize": 13,
#       "fontWeight": 500
#     }
#   },
#   "data": {
#     "name": "data-ad34afc27c89be127544f878c799b6ec"
#   },
#   "mark": "circle",
#   "encoding": {
#     "color": {
#       "type": "nominal",
#       "field": "SALARY_TYPE"
#     },
#     "x": {
#       "type": "quantitative",
#       "axis": {
#         "title": "SALARY"
#       },
#       "field": "SALARY",
#       "scale": {
#         "domain": [
#           60,
#           5000
#         ]
#       }
#     },
#     "y": {
#       "type": "quantitative",
#       "axis": {
#         "title": "JOB_CODE"
#       },
#       "field": "JOB_CODE",
#       "scale": {
#         "domain": [
#           2120,
#           99982
#         ]
#       }
#     }
#   },
#   "height": 150,
#   "selection": {
#     "selector129": {
#       "type": "interval",
#       "bind": "scales",
#       "encodings": [
#         "x",
#         "y"
#       ]
#     }
#   },
#   "width": 160,
#   "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json",
#   "datasets": {
#     "data-ad34afc27c89be127544f878c799b6ec": [
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 94985,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 94985,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 37010,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 37010,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 37010,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 37040,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 44230,
#         "SALARY_TYPE": null,
#         "SALARY": 260
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 99560,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 2970,
#         "SALARY_TYPE": null,
#         "SALARY": 900
#       },
#       {
#         "JOB_CODE": 3210,
#         "SALARY_TYPE": null,
#         "SALARY": 275
#       },
#       {
#         "JOB_CODE": 3290,
#         "SALARY_TYPE": null,
#         "SALARY": 110
#       },
#       {
#         "JOB_CODE": 3480,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 3480,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 3480,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 3920,
#         "SALARY_TYPE": null,
#         "SALARY": 165
#       },
#       {
#         "JOB_CODE": 3920,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 3920,
#         "SALARY_TYPE": null,
#         "SALARY": 110
#       },
#       {
#         "JOB_CODE": 3920,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 3920,
#         "SALARY_TYPE": null,
#         "SALARY": 110
#       },
#       {
#         "JOB_CODE": 3920,
#         "SALARY_TYPE": null,
#         "SALARY": 110
#       },
#       {
#         "JOB_CODE": 11090,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 11090,
#         "SALARY_TYPE": null,
#         "SALARY": 900
#       },
#       {
#         "JOB_CODE": 21950,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 37040,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 39160,
#         "SALARY_TYPE": null,
#         "SALARY": 125
#       },
#       {
#         "JOB_CODE": 39160,
#         "SALARY_TYPE": null,
#         "SALARY": 125
#       },
#       {
#         "JOB_CODE": 39160,
#         "SALARY_TYPE": null,
#         "SALARY": 125
#       },
#       {
#         "JOB_CODE": 39160,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 39965,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 74460,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 74460,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 87770,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 95790,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 95790,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 95790,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 95945,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 95945,
#         "SALARY_TYPE": null,
#         "SALARY": 180
#       },
#       {
#         "JOB_CODE": 95945,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 95945,
#         "SALARY_TYPE": null,
#         "SALARY": 180
#       },
#       {
#         "JOB_CODE": 96390,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 96390,
#         "SALARY_TYPE": null,
#         "SALARY": 180
#       },
#       {
#         "JOB_CODE": 96390,
#         "SALARY_TYPE": null,
#         "SALARY": 800
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 98550,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 98550,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 98550,
#         "SALARY_TYPE": null,
#         "SALARY": 180
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 280
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 145
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 190
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 99430,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99430,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99430,
#         "SALARY_TYPE": null,
#         "SALARY": 90
#       },
#       {
#         "JOB_CODE": 99430,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99430,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99430,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99890,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99890,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99890,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 99890,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99890,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 39997,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 99981,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 99981,
#         "SALARY_TYPE": null,
#         "SALARY": 125
#       },
#       {
#         "JOB_CODE": 99981,
#         "SALARY_TYPE": null,
#         "SALARY": 185
#       },
#       {
#         "JOB_CODE": 99981,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 99981,
#         "SALARY_TYPE": null,
#         "SALARY": 185
#       },
#       {
#         "JOB_CODE": 99981,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 99981,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99981,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99982,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99982,
#         "SALARY_TYPE": null,
#         "SALARY": 125
#       },
#       {
#         "JOB_CODE": 99982,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 99982,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 21110,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 42240,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 88040,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 88040,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 88040,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 33130,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 43320,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98645,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 21950,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 33990,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 42240,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 99480,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 37040,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 99960,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 550
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 550
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 180
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 11090,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 43250,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99960,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 22404,
#         "SALARY_TYPE": null,
#         "SALARY": 550
#       },
#       {
#         "JOB_CODE": 21950,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 39985,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 350
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99360,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 21950,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 33130,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 42240,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 42240,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 95510,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99580,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 99580,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99960,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99960,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99960,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 99960,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 2290,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 2290,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 2290,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 3150,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 90
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 110
#       },
#       {
#         "JOB_CODE": 11090,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 16230,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 16230,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 16230,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 16230,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 21110,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 32120,
#         "SALARY_TYPE": null,
#         "SALARY": 420
#       },
#       {
#         "JOB_CODE": 32120,
#         "SALARY_TYPE": null,
#         "SALARY": 420
#       },
#       {
#         "JOB_CODE": 37040,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 37040,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 39965,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 39965,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 43220,
#         "SALARY_TYPE": null,
#         "SALARY": 1200
#       },
#       {
#         "JOB_CODE": 43250,
#         "SALARY_TYPE": null,
#         "SALARY": 1000
#       },
#       {
#         "JOB_CODE": 43250,
#         "SALARY_TYPE": null,
#         "SALARY": 1050
#       },
#       {
#         "JOB_CODE": 45290,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 84910,
#         "SALARY_TYPE": null,
#         "SALARY": 580
#       },
#       {
#         "JOB_CODE": 84910,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 84910,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 84910,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 85110,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 87460,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 87460,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 87460,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 87460,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 87460,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 88035,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 88035,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 88035,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 95120,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 95120,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 95120,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 95510,
#         "SALARY_TYPE": null,
#         "SALARY": 90
#       },
#       {
#         "JOB_CODE": 96120,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 96125,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 96125,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 96390,
#         "SALARY_TYPE": null,
#         "SALARY": 550
#       },
#       {
#         "JOB_CODE": 96390,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 96390,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 98540,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 75
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 99580,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 99580,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99580,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98516,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 42240,
#         "SALARY_TYPE": null,
#         "SALARY": 350
#       },
#       {
#         "JOB_CODE": 45290,
#         "SALARY_TYPE": null,
#         "SALARY": 350
#       },
#       {
#         "JOB_CODE": 43494,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 12120,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 19385,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 55220,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 9310,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 9480,
#         "SALARY_TYPE": null,
#         "SALARY": 780
#       },
#       {
#         "JOB_CODE": 9480,
#         "SALARY_TYPE": null,
#         "SALARY": 850
#       },
#       {
#         "JOB_CODE": 15980,
#         "SALARY_TYPE": null,
#         "SALARY": 800
#       },
#       {
#         "JOB_CODE": 21360,
#         "SALARY_TYPE": null,
#         "SALARY": 2600
#       },
#       {
#         "JOB_CODE": 43240,
#         "SALARY_TYPE": null,
#         "SALARY": 700
#       },
#       {
#         "JOB_CODE": 43270,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 44230,
#         "SALARY_TYPE": null,
#         "SALARY": 495
#       },
#       {
#         "JOB_CODE": 45290,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 45290,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 45290,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 45290,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 55220,
#         "SALARY_TYPE": null,
#         "SALARY": 170
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 43240,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 39985,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 87580,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 87580,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 87580,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 87580,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98530,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98530,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98530,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99560,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99560,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 99560,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99560,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 53190,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 84910,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 43250,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 96990,
#         "SALARY_TYPE": null,
#         "SALARY": 130
#       },
#       {
#         "JOB_CODE": 96990,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 58990,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 3460,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 11090,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 21110,
#         "SALARY_TYPE": null,
#         "SALARY": 900
#       },
#       {
#         "JOB_CODE": 21140,
#         "SALARY_TYPE": null,
#         "SALARY": 1350
#       },
#       {
#         "JOB_CODE": 21560,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 33130,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 43220,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 43220,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 43260,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 96910,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 39997,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 43496,
#         "SALARY_TYPE": null,
#         "SALARY": 1300
#       },
#       {
#         "JOB_CODE": 62440,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98530,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 240
#       },
#       {
#         "JOB_CODE": 58990,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 60
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 44548,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 45290,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 62440,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 62450,
#         "SALARY_TYPE": null,
#         "SALARY": 70
#       },
#       {
#         "JOB_CODE": 85155,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 85155,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 85155,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 62440,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 62440,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 32120,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 43220,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 58990,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 58990,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 21950,
#         "SALARY_TYPE": null,
#         "SALARY": 1000
#       },
#       {
#         "JOB_CODE": 33130,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 37040,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 39985,
#         "SALARY_TYPE": null,
#         "SALARY": 1000
#       },
#       {
#         "JOB_CODE": 96390,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 98630,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98565,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 2290,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 42160,
#         "SALARY_TYPE": null,
#         "SALARY": 550
#       },
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 350
#       },
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 83190,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 94990,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 96391,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 96391,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 2360,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 2120,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 62450,
#         "SALARY_TYPE": null,
#         "SALARY": 140
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 62460,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 62450,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 62450,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 11090,
#         "SALARY_TYPE": null,
#         "SALARY": 1200
#       },
#       {
#         "JOB_CODE": 58990,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 22403,
#         "SALARY_TYPE": null,
#         "SALARY": 2500
#       },
#       {
#         "JOB_CODE": 37010,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 45290,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 84970,
#         "SALARY_TYPE": null,
#         "SALARY": 300
#       },
#       {
#         "JOB_CODE": 84970,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 84970,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 84970,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 84970,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 84970,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 93990,
#         "SALARY_TYPE": null,
#         "SALARY": 80
#       },
#       {
#         "JOB_CODE": 2410,
#         "SALARY_TYPE": null,
#         "SALARY": 650
#       },
#       {
#         "JOB_CODE": 2980,
#         "SALARY_TYPE": null,
#         "SALARY": 1050
#       },
#       {
#         "JOB_CODE": 11080,
#         "SALARY_TYPE": null,
#         "SALARY": 1400
#       },
#       {
#         "JOB_CODE": 21950,
#         "SALARY_TYPE": null,
#         "SALARY": 5000
#       },
#       {
#         "JOB_CODE": 42240,
#         "SALARY_TYPE": null,
#         "SALARY": 425
#       },
#       {
#         "JOB_CODE": 43240,
#         "SALARY_TYPE": null,
#         "SALARY": 1500
#       },
#       {
#         "JOB_CODE": 53265,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 53265,
#         "SALARY_TYPE": null,
#         "SALARY": 620
#       },
#       {
#         "JOB_CODE": 53265,
#         "SALARY_TYPE": null,
#         "SALARY": 500
#       },
#       {
#         "JOB_CODE": 87480,
#         "SALARY_TYPE": null,
#         "SALARY": 275
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 200
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 450
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 325
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 245
#       },
#       {
#         "JOB_CODE": 98515,
#         "SALARY_TYPE": null,
#         "SALARY": 225
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 74461,
#         "SALARY_TYPE": null,
#         "SALARY": 145
#       },
#       {
#         "JOB_CODE": 74461,
#         "SALARY_TYPE": null,
#         "SALARY": 155
#       },
#       {
#         "JOB_CODE": 43260,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 62190,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 33131,
#         "SALARY_TYPE": null,
#         "SALARY": 400
#       },
#       {
#         "JOB_CODE": 43240,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 53190,
#         "SALARY_TYPE": null,
#         "SALARY": 250
#       },
#       {
#         "JOB_CODE": 53190,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 100
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 150
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99320,
#         "SALARY_TYPE": null,
#         "SALARY": 120
#       },
#       {
#         "JOB_CODE": 99410,
#         "SALARY_TYPE": null,
#         "SALARY": 130
#       },
#       {
#         "JOB_CODE": 39997,
#         "SALARY_TYPE": null,
#         "SALARY": 600
#       },
#       {
#         "JOB_CODE": 3560,
#         "SALARY_TYPE": null,
#         "SALARY": 265
#       }
#     ]
#   },
#   "vislib": "vegalite"
# }

# %% [markdown]
# Lux provides a powerful abstraction for working with collections of visualizations based on a partially specified queries. Users can provide a list or a wildcard to iterate over combinations of filter or attribute values and quickly browse through large numbers of visualizations. The partial specification is inspired by existing work on intent languages for visualization languages

# %% [markdown]
# # Lux.Clause

# %% [markdown]
# There’s only so much one can accomplish with string-based intent specifications, lux.Claus offers a more complex and expressive way of specifying intent. Additionally, it allows us to override auto-inferred details about the plots, such as the attribute’s default axis or the aggregation function used for the quantitative attributes.

# %%
df.intent = [lux.Clause(attribute='SALARY', channel='y')]
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.intent = ["SALARY",lux.Clause("SALARY",aggregation="sum")]
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# Lux offers data scientists a quick way to easily explore patterns and profile their data through automated visualizations inside of their Jupyter notebook. The ability to quickly slice and dice datasets without the need for extensive code provides efficiency and helps speed up the end-to-end process of analyzing new datasets.
#
# The library also includes the ability to export graphs in a number of ways, including into code that can be called outside of the Lux widget itself giving data scientists a quick and easy way to share their analysis.
