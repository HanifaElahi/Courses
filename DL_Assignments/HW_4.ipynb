# %% [markdown]
# # Build your `Deep Convolutional Generative Adversarial Network (DCGAN)` for Deep Learning on Handwritten Digits `Image generation` Task

# %% [markdown]
# ## Annotations in cell of this Notebook:
#
# <font color='red'>Read carefully the Annotations below to understand what to write in the Notebook and what to answer in the Course Shell.</font>
#
#  `##` is the python comments for assignment requirements and/or descriptions to the code below.
#
# `???` is the marker of the place that you should REPLACE with your own python code (either name of function[s], name of variable[s], expression[s], or a whole code line etc.), which should be able to be executed without errors. <strong>You may also find some inspirations from previous HomeWork assignment to write desired code for similar purpose/functionality </strong>
#
# `##-Qx: ` is the numbered identifier to indicate the question you should answer in the Course Shell for this homework. For example    `##-Q1: ` and `##-Q6: ` .
#
# [`clickable link`]() is some tip/hint resources you many refer to in addition to your learning resources from this course or your self explorations.

# %% [markdown]
# ## Task Overview
# <img src="https://miro.medium.com/max/1400/1*N3nT9AXVnsFBta2R1eEMjg.png" width="500">
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　<strong>A Task Schema Diagram</strong>
#
# Generative Adversarial Networks (GANs) is a framework to train generative models, such as deep convolutional neural networks for generating images. GAN composed of two models which are trained simultaneously by an adversarial process. A generator model ("the artist") learns to create fake images that look real, while a discriminator model ("the art critic") learns to tell real images apart from fakes.
#
# During training, the generator progressively becomes better at creating images that look real, while the discriminator becomes better at telling them apart. The process reaches equilibrium when the discriminator can hardly distinguish real images from fakes.
#
# For a simple GAN the generator is build as a simple fully connected network. The generator of a Deep Convolutional Generative Adversarial Network (DCGAN) are mainly composes of convolution layers without max pooling with convolutional stride and transposed convolution (Fractionally-strided convolution or Deconvolution) for the downsampling and the upsampling of 2D images.
#
#
# You will conduct a `Image generation` task, by `building` a DCGAN architecture with Python to generate `fake images` from random `noise input`, that after proper `training` of the model it would look like images of `real handwritten digits`.
#
# The `TensorFlow 2.x` platform and its integrated version of `Keras API` (versus the traditional Keras Package) should be the handy tools for you to complete this task. Please take advantage of the official well supported TensorFlow & Keras [`Help Documentations`](https://www.tensorflow.org/api_docs/python/tf/keras) for correct usages of the API and functions.

# %%
## Import related Modules for TensorFlow framework and Keras API

## import the TensorFlow and give it alias "tf" 
import tensorflow as tf

## import the `Keras` API from TensorFlow 
from tensorflow import keras

##-Q1: copy your composed code in the line above to answer corresponding question in the Course Shell 

## import the namespace "layers" and "optimizer" of Keras from Tensorflow 
##   - use comma and exactly one space to seperate each namespace

from tensorflow.keras import layers, optimizers

##-Q2: copy your composed code in the line above to answer corresponding question in the Course Shell

## import the Numpy package and give it alias "np" 
import numpy as np

import matplotlib.pyplot as plt

# %%
## Record the starting time of runing DCGAN project
## Create a image folder to store generated fake images for every interval during training
import os
from datetime import datetime
datetime_now = datetime.now()
print(f"DCGAN Project starts at {datetime_now}")
datetime_now = datetime_now.strftime("%Y%d%m_%H%M%S")
if os.path.exists('dcgan_fake_images'):       
    os.rename("dcgan_fake_images", f"dcgan_fake_images_{datetime_now}")    
    os.makedirs('dcgan_fake_images')
else:        
    os.makedirs('dcgan_fake_images')
# Out:
# DCGAN Project starts at 2023-05-16 15:59:39.374942

# %% [markdown]
# ## Prepare Dataset
#
# ### The Image Dataset of MNIST Handwritten Digits - Introduction

# %% [markdown]
# The [`MNIST`](http://yann.lecun.com/exdb/mnist/) database (Modified National Institute of Standards and Technology database) is a large database of handwritten digits that is widely used for training and testing Deep Learning Models.
#
# The images in the dataset contains small square images with pixels in grayscale, and each image present a real handwritten single digits between 0 and 9.
#
# The image genration task is to generate fake images out of noise inputs and have the fake images looks like a handwritten digit.

# %% [markdown]
# ### Load Data
#
# Load the MNIST dataset distributed with Keras.

# %%
## Load the MNIST data from the Keras in Tensorflow framework
mnist_data = keras.datasets.mnist
  
## We will only use the images to train the DCGAN, so use '_' to replace other variable locations
##   Since we are not trying to train model to classify into correct labels 
##   We only need to identify if a image is real or fake as 1 or 0
## replace ONLY the '???' in the code line below:
(images_train, _),(_, _) = mnist_data.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# ###  Explore Data

# %%
## Find out the datatype, dimensions, and min/max value (i.e. value range) of the loaded data `images_train` 
## Feel free to explore all aspects that could help you understand the data

print("Data type: ", images_train.dtype)
print("Dimensions: ", images_train.shape)
print("Value range: ({}, {})".format(images_train.min(), images_train.max()))

# ...
# Out:
# Data type:  uint8
# Dimensions:  (60000, 28, 28)
# Value range: (0, 255)

# %%
## Define a function for visualizing some images
def images_show(images, dim=(1,6), figsize=(12,6), num_postfix=-1):
    plt.figure(figsize=figsize)
    for i in range(images.shape[0]):
        plt.subplot(dim[0], dim[1], i+1)
        plt.imshow(images[i], cmap='Greys_r', interpolation='nearest')
        plt.axis('off') 
    plt.savefig(f'dcgan_fake_images/fake_images_iter_{num_postfix:05d}.png') 
    plt.pause(0.1)

# %%
## Call the function images_show to show first 6 images in the loaded data, i.e. images_train

loaded_image_samples = images_train[:6]
images_show(loaded_image_samples)  

##-Q3: What are the code you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the code comment)?

# %% [markdown]
# ### Preprocess data

# %%
## To faciliate the model training, we would preprocess to normalize and reshape the images

def images_preprocess(images):
    ## Normalize the input images to the range of [-1, 1] 
    images = images / 127.5 - 1
    
    ## Convert dimension of all grayscale images to be enforce to have a color channel in its dimensions
    ##   i.e. convert origianl 3D tensor (number_of_data, image_height, image_width) of `images_train`
    ##        to 4D tensor by adding the addiontal dimension as the color channel
    ##   - fill in only the number values to replace the ??? below:
    images = images.reshape(len(images), 28, 28, 1).astype('float32')
      
    ##-Q4: What are the number values you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the comment)? 
    
    return images

## Use the function images_preprocess to preprocess the loaded data `images_train`  
images_preprocessed = images_preprocess(images_train)
##-Q5: What are the code you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the comment)?

# %% [markdown]
# ### Prepare dataset

# %%
## Prepare dataset from the preprocessed image data by shuffle and batch 

## set parameter BUFFER_SIZE as the total number of images in the loaded data `images_train`
BUFFER_SIZE = images_preprocessed.shape[0]
    
## set parameter BATCH_SIZE as 64
BATCH_SIZE = 64

## create dataset for real images 
images_data = tf.data.Dataset.from_tensor_slices(images_preprocessed)
def get_dataset_real(dataset, buffer=BUFFER_SIZE, batch=BATCH_SIZE, drop_remainder = True):
    ## Shuffle and Batch to prepare the dataset for real images
    dataset = dataset.shuffle(buffer).batch(batch, drop_remainder = drop_remainder).prefetch(1)
    return dataset

# %%
## create noises for generating fake images during the training stage
 
## use a 1D random vector as the noise input 
##   for the generator model to create one fake image later 
## Set the dimension of the vector (i.e. NOISE_SIZE) as 100 
##   i.e. the number of input 
NOISE_SIZE = 100

## create a batch of random vectors that each is in the range of [-1, 1] (as noises)  
##   i.e. random vectors for one batch
def get_noise_one_batch(batch_size=BATCH_SIZE, noise_size=NOISE_SIZE):
    noice_one_batch = np.random.uniform(-1, 1, (batch_size, noise_size))
    return noice_one_batch

# %% [markdown]
# ## Build architecture of your DCGAN model
#
# DCGAN is based on GAN, which composed of two models in neural networks:
#
# - The first model is called a **Generator** and it aims to generate new data similar to the real one. In DCGAN it would generate an unexisted image that we call fake image for this project.
#
# - The second model is named the **Discriminator** and it aims to recognize if a data is ‘real’ — belongs to the original dataset; Or if it is ‘fake’ — generated by a forger. Whose output is a binary 1 or 0.
#
#
#
# The basic building block of neural network is the layer.
# You will configure each layer of your model, then compiling the model.
#
#
#
# <br>
#
# For this task you are required to chain together layers as the architecture of the DCGAN.
#
# **Besides the layers you've already practiced and familiared with** in the **previous assignments** (E.g. **Dense, Convolutional, Flatten** layers etc.),
#
# the following  [**new types of layers**](https://www.tensorflow.org/api_docs/python/tf/keras/layers) might also needed in this task. Their API references listed below (as how to apply their corresponding **parameters** to configure the layer) might provide you more inspirations.
#
# - [Reshape](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Reshape)
#
# - [Conv2DTranspose](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2DTranspose)
#
# - [LeakyReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LeakyReLU)

# %% [markdown]
# ### Build the Generator Model
#
#
# This Generator Model will receive noise vectors as inputs, and generated fake images as output;
#
# A vector in the inputs would be converted and upsampled several times until reaching the same size of a real image.

# %%
## Build a Generator model by stacking keras layers sequentially  
 
generator = keras.Sequential([        
##-Q6: What is the function name that you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the comment)? 

    ## *** READ *VERY CAREFULLY* Below What is DESCRIBED and REQUIRED to be FULFILLED *** 
    
    ## Apply a fully-connected layer WITH bias, 
    ##   to receive and feature mapping the input, i.e. the noice vector
    layers.Dense(7*7*128, input_shape=(NOISE_SIZE,), use_bias=True),   
    ##-Q7: What are the code that you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the comment)? 
    
    ## Add a Reshape layer to change the output from previous 1D input layer into 3D 
    ##   which has 7X7 as size of generated 2D latent image 
    ##   with 128 features in the 3rd dimension
    layers.Reshape([7, 7, 128]), 
    
    ## Build a transposed convolution layer WITHOUT bias 
    ##      to do inversed convolution as a way to do learnable Upsampling;
    ##   which has number of filters that equals to HALF of the 
    ##      feature dimension of the output from previous layer; 
    ##   5 X 5 as the kernel size;
    ##   stride step as 2 for all of its spatial dimensions; and 
    ##   padding with zeros evenly to the surroundings of the input. 

    layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False),

    ##-Q8: What are the code that you should put in place of the ??? in the above code line 
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    
    ##-Q9: After upsampling by transposed convolution layer with the required parameter configurations,
    ##      What is the dimension of the 2D latent image that was 7X7 output from previous layer? 
       
    
    ## Add a Batch Normalization layer which would stabilize the learning procedure
    ##   by standardizing activations from the prior layer to 
    ##   have normal distribution with the mean value of 0 and unit variance  
    layers.BatchNormalization(),  
    
    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    ##   which still allow some negative value to pass through the network for continue learning
    ##   even if it is negative, by multiply which with alpha     
    layers.LeakyReLU(alpha=0.2), 
    
    
    ## Build a transposed convolution layer WITHOUT bias;
    ##   which has number of filters that equals to HALF of the 
    ##      feature dimension of the output from previous layer; 
    ##   3 X 3 as the kernel size; 
    ##   stride step as 2 for all of its spatial dimensions; and 
    ##   padding with zeros evenly to the surroundings of the input. 
    ## ???.???(???, (???, ???), strides=(???, ???), padding='???', use_bias=???),

    layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same', use_bias=False),

    ##-Q10: What is the code line that you should put in place of the ??? line in the above  
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    ##   - use exactly only one space when needed, use only exactly one space after comma when comma is needed
       
    ##- Think about : After upsampling by this transposed convolution layer with the required parameter configurations,
    ##      What is the dimension of the 2D latent image that was output from its previous layer? 
 
    
    ## Add a Batch Normalization layer  
    layers.BatchNormalization(), 
    
    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    layers.LeakyReLU(alpha=0.2),
    
    ## Build a transposed convolution layer WITHOUT bias;
    ##   which has a number of filters 
    ##      that would make the output, i.e. the generated image, 
    ##      to have only 1 feature dimension, i.e. 1 color channel
    ##   3 X 3 as the kernel size; 
    ##   SET stride step as a PROPER number 
    ##      that would make the output, i.e. the generated image, 
    ##      to have its first 2 dimensions (i.e. height and width), same as the loaded mnist real image
    ##      i.e. the generated image in same image size as the real image.        
    ##   padding with zeros evenly to the surroundings of the input;
    ##   and CHOOSE an activation function that could make 
    ##      the range of output fake image's pixel values the SAME as preprocessed real iamge 
    ##      i.e. a range in [-1, 1]  

    layers.Conv2DTranspose(1, (3, 3), strides=(1, 1), padding='same', use_bias=False, activation='tanh'),
    
    ##-Q11: What are the code that you have put in place of the 1st,2nd,3rd and 6th ??? in the above code line 
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
 
    ## A following Reshape layer is to make sure the output fake image has same dimensions as the real images.
    ##   - if error occurs (dimension not match) it may suggest you to check if the previous layer configuration (e.g. strides) is correct
    layers.Reshape([28, 28, 1])
])

## suggestion: take a look at your model's architecture by printing it out 
##   and think it through about how the transposed convolution generate the final image through upsampling

# %% [markdown]
# ### Build the Discriminator Model
#
#
# This Discriminator Model in DCGAN is basically a normal **CNN*** (So you could **recall how you build your CNN model in previous assignment**) that can be trained for binary classification, to identify real or fake images.
#
# The Discriminator Model will receive images as inputs, and binary values 1 or 0 as the outputs, representing the classification of the input images to be real or fake.

# %%
## set the input dimension for Discriminator Model
##   to the image shape in the tensor format (image_height, image_width, color_channels)
image_dim = (28, 28, 1)


# Build a tf.keras.Sequential model by stacking layers

discriminator = keras.Sequential([      
    ## Build a Convolutional layer that 
    ##   `input_shape` equal to the image dimention,  
    ##   has 64 filters, 
    ##   5 X 5 as the kernel size, 
    ##   stride step as 2,and 
    ##   padding with zeros evenly to the surroundings of the input.     
    ## - ref: ???.???(???, (???, ???), strides=(???, ???), input_shape=image_dim, padding='???'),
    layers.Conv2D(64, (5, 5), strides=(2, 2), input_shape=image_dim, padding='same'),

    
    ##-Q12: What is the code line that you should put in place of the ??? line in the above  
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    ##   - use exactly only one space when needed, use only exactly one space after comma when comma is needed
       
    
    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    layers.LeakyReLU(alpha=0.2),
    
    ## Add a Droupout layer to reduce overfitting     
    ##   and set the rate to be 0.3 of the input units for dropping out  
    layers.Dropout(rate=0.3),
    
    
    ## Build a Convolutional layer that   
    ##   has 128 filters, 
    ##   3 X 3 as the kernel size, 
    ##   stride step as 2,and 
    ##   padding with zeros evenly to the surroundings of the input.
    layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(2, 2), padding='same'),

    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    layers.LeakyReLU(alpha=0.2),
    
    ## Add a Droupout layer to reduce overfitting     
    ##   and set the rate to be 0.3 of the input units for dropping out  
    layers.Dropout(0.3), 
    
    
    ## Build a Convolutional layer that   
    ##   has 256 filters, 
    ##   3 X 3 as the kernel size, 
    ##   stride step as 2,and 
    ##   padding with zeros evenly to the surroundings of the input.
    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    ## Add a Droupout layer to reduce overfitting     
    ##   and set the rate to be 0.3 of the input units for dropping out  
    layers.Conv2D(256, (3,3), strides=(2,2), padding='same'),      
    layers.LeakyReLU(alpha=0.2),     
    layers.Dropout(0.3),     
    
    
    ## Biuld A Flatten layer to flatten the input  
    layers.Flatten(),    

    ##-Q13: What is the code line that you should put in place of the ??? line in the above  
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    ##   - use exactly only one space when needed, use only exactly one space after comma when comma is needed
       
    
    ## Apply a `full-connected` output layer 
    ##   with a unit number that can output a binary value;
    ##   - choose a proper activation function 
    ##      for this goal of *binary output* (binary classification task)  
    layers.Dense(units=1, activation='sigmoid')
   
    ##-Q14: What are the code that you should put in place of the ??? in the above code line 
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
 
])


## suggestion: take a look at your model's architecture by printing it out 
##   and think it through as well as compare with your previous CNN model

# %% [markdown]
# ##### Compile Discriminator Model first
#
# Before the model is ready for training, it needs a few more settings. These are to be added during the [model's compiling](https://www.tensorflow.org/api_docs/python/tf/keras/Model) step:
#
# - [Optimizer](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) : This is how the model is updated based on the data it sees and its loss function.
# - [Loss function](https://www.tensorflow.org/api_docs/python/tf/keras/losses) : This measures how accurate the model is during training. You want to minimize this function to "steer" the model in the right direction.

# %% [markdown]
# Choose your optimizer:

# %%
## Set your optimizer for compiling the models later
## Select an optimizer that implements the Adam algorithm, 
##   and validate to decide a proper learning rate for your model 
# my_optimizer = Adam(learning_rate=0.001)

my_optimizer = optimizers.Adam(learning_rate=0.001)

##-Q15: What are the code line that you should put in place of the ??? in the above code line 
##     to fully fulfill its purpose of design (requirements in its above comments)?

# %% [markdown]
# Compile Discriminator Model:

# %%
## Compile the Discriminator model with your chosen optimizer, 
##   and use Binary cross-entropy as losses, 
discriminator.compile(optimizer=my_optimizer,
        loss=keras.losses.BinaryCrossentropy()
       )                     

##-Q16: What are the code that you should put in place of the ??? in the above code line 
##     to fully fulfill its purpose of design (requirements in its above comments)?

# %% [markdown]
#
# ### Build the DCGAN Model
#
#
# Build the DCGAN by concatenating the Generator and Discriminator into one sequential.
#
# The DCGAN Model will receive noise vectors as inputs, and a binary values 1 or 0 as the outputs, representing the classification of the input images to be real or fake.
#
# The Generator model is only concerned with the discriminator’s performance on fake examples. Therefore, we will mark all of the layers in the Discriminator as not trainable when it is part of the GAN model so that they can not be updated and overtrained on fake examples.

# %%
## make discriminator not-trainable as of now
discriminator.trainable = False

## Combine both Generator and Discriminator Models
dcgan = keras.Sequential([     
    generator,   
    discriminator      
])


##-Q17: What is the `total number` of params (i.e. weights) , 
##      including the Non-trainable params e.g. from the Discriminator part, 
##      in the whole DCGAN Model build above?
##      be careful in the calculations, For example. with or without bias.

# %%
dcgan.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 28, 28, 1)         857376
#
#  sequential_1 (Sequential)   (None, 1)                 374785
#
# =================================================================
# Total params: 1,232,161
# Trainable params: 857,184
# Non-trainable params: 374,977
# _________________________________________________________________

# %% [markdown]
# ##### Compile DCGAN
#
# And then compile the whole DCGAN

# %%
## Compile the DCGAN model as a whole with your chosen optimizer, 
##   and use Binary cross-entropy as losses, 
dcgan.compile(optimizer=my_optimizer, loss=keras.losses.BinaryCrossentropy())

# %% [markdown]
# ## Train the model
#
# Train the DCGAN to improve the ability of generating good fake images by the Generator.

# %% [markdown]
# Prepare 6 random noice vectors, to check and compare how the generated fake images on same 6 inputs are improved over the training procedure.

# %%
## create random noice inputs to checking the corresponding generated fake images 

## create random noise inputs of 6
##    which will be later used for comparison of the generated images
##    on these same sample noises during the training 
noise_inputs_check = get_noise_one_batch(6)  
## generate the initial output images before training
images_outputs_check = generator.predict(noise_inputs_check)

## Show the 6 generated images: 
images_show(images_outputs_check, num_postfix=-1)
# Out:
# 1/1 [==============================] - 0s 355ms/step

# %% [markdown]
# ##### Train Discriminator Model and DCGAN Model
#
# In each training loop, the Discriminator Model is first trained to better classify real images (drawn from the real image dataset ) and fakes images (produced by the Generator Model based on random noice as input).
#
# The Discriminator in DCGAN was first marked as not trainable to train only weights of layers in the Generator of DCGAN Model to help better generate fake images like real.

# %%
## Define training parameters  

## set epochs size/count 
##  it is assigned a initial value 1 TEMPORARILY, you need to replace it to your tunned value eventually.
EPOCHS = 4   ### 1 is a temporary value that you need to update before submitting 


## Calculated the Number of batches based on the loaded data `images_train`  and the size of a batch
BATCHS = np.floor(BUFFER_SIZE/BATCH_SIZE).astype('int')

## Set the interval as 300 
##   to show generated images by the Generator trained so far in the training procedure
##   on the same 6 noise vector inputs.
##   i.e. Display every 300 iterations the 6 generated fake images as training keeps improving it
iter_interval = 300

## Define binary labels that represent real and fake outputs for each batch training
labels_real = np.ones((BATCH_SIZE, 1))
labels_fake = np.zeros((BATCH_SIZE, 1))

# %% [markdown]
# ###  <font color='red'>NOTICE:</font>
#
# <font color='red'>Depending on your EPOCHS count, your computer computation capability, etc. the training procedure could take HOURS </font>
#
# You could temporarily replace the variable name `EPOCHS` in the below code cell to be a small value for testing.  After tunning all other parameters above this cell, you can then replace that small value back to the original variable name `EPOCHS`, so your setting on the `EPOCHS` in the above code cell could take effect.
#
# For example, if you replace　　`for epoch in range(0, EPOCHS):`　　to be　 　`for epoch in range(0, 1):`
#
# and execute the below code cell, the DCGAN will only be trained for 1 epoch for all the batches, and stop there.
#
# <br>
#
# After that you can keep manually changing it to be 　　`for epoch in range(1, 2):`
#
# and execute the below code cell again (without needing to restart the whole notebook), the DCGAN will keep beeing trained for the 2nd epoch, and the training will continue based on the parameters already learned from the 1st epoch.
#
# As long as your computer, Jupyter notebook local server, and this .ipynb, are not colsed, you should be able to keep on the training procesure, instead of training all over again.
#
# For example if you want to run the 3rd epoch, then keep manually change it to be 　　 `for epoch in range(2, 3):`
#
# then the model will continued to be trained upon the parameters learned from the 2nd epoch
#
# <br>
#
# This way of manually start the next epoch round could let you have more controls on the tunning or debugging, and have a better idea how many epochs your model would eventually need. 　Note re-run the below cell will overwrite the output so you won't be able to see the image plots generated from previous epoch, but you can always go into your image subfolder to inspect.
#
# After you tunned to decide a satisfied epoch count (as well as other parameters), then you can assign that value to the variable `EPOCHS` in the above code cell, and change the bellow cell back to `for epoch in range(0, EPOCHS):`, and save the .ipynb before colse and halt it, then reopen the .ipynb to have a full run-from-beginning, to complete this assignment for the submission.

# %%
## Start Model Training in the iterations

## Record the Starting time of runing DCGAN training
datetime_now = datetime.now()
print(f"~~~ DCGAN training starting at {datetime_now} \n\n ")  

for epoch in range(0, EPOCHS): 
    ## generate new dataset of real images for each epoch
    real_dataset = get_dataset_real(images_data)
    
    for batch, images_real in enumerate(real_dataset):
        
        ## Train Discriminator seperately:
        
        ## Make Discriminator Trainable for now
        ##   i.e.set the Discriminator Model trainable to be trained on real and fake images
        discriminator.trainable = True     
        
        ## Batch Train Discriminator Model on a batch of real images with them labeled as real 
        d_loss_real = discriminator.train_on_batch(images_real, labels_real)
        
        ## create a random noise batch inputs and pass which into the Generator to generate fake images
        noise_inputs = get_noise_one_batch()
        images_fake = generator.predict(noise_inputs)
                          
        ## Train Discriminator Model on a batch of fake images with them labeled as fake 
        d_loss_fake = discriminator.train_on_batch(images_fake, labels_fake)
                          
            
        ## Train DCGAN model     
        
        ## Make Discriminator Not-trainable for now
        ##   i.e. set the Discriminator Model NOT trainable 
        ##        to only update layer weights of Generator            
        discriminator.trainable = False   
        ##-Q18: What is the code line that you should put in place of the ??? in the above line 
        ##     to fully fulfill its purpose of design (requirements in its above comments)? 
        
        ## create a random noise batch inputs and pass which into the DCGAN later
        noise_inputs = get_noise_one_batch()
        
        ## Batch Train DCGAN Model on a batch of noise inputs with them labeled as real 
        ##   to fool the Discriminator with the fake images generated by Generator but labeled as real

        dcg_loss = dcgan.train_on_batch(noise_inputs, labels_real) 

        
        ##-Q19: What is the code line that you should put in place of the ??? in the above line 
        ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    
        ## Print training progress with model losses  on the intervals  
        ##   and Show fake images generated on same 6 noise inputs 
        ##            which are also saved in the folder for comparison later
        iteration = (epoch * BATCHS) + (batch + 1)  

        if iteration % 5 == 0:
            print(f"=== Iter: {iteration} : d_loss_real: {d_loss_real:.9f}, d_loss_fake: {d_loss_fake:.9f}, dcg_loss: {dcg_loss:.9f} - in Epoch {epoch + 1}/{EPOCHS} - Batch {batch+1}/{BATCHS}")

        if iteration % iter_interval == 0: 
            images_check = generator.predict(noise_inputs_check)
            images_show(images_check, num_postfix=iteration)
            print("*** time now: ", datetime.now()) 
            
## Record the Ending time of runing DCGAN training
datetime_now = datetime.now()
print(f"\n\n ~~~ DCGAN trainging ends at {datetime_now}")
# Out:
# ~~~ DCGAN training starting at 2023-05-15 06:59:02.852148
#
#
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 96ms/step
# === Iter: 2815 : d_loss_real: 0.346453577, d_loss_fake: 0.288459122, dcg_loss: 2.406425953 - in Epoch 4/1 - Batch 4/937
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 65ms/step
# === Iter: 2820 : d_loss_real: 0.289261997, d_loss_fake: 0.407054156, dcg_loss: 2.146087646 - in Epoch 4/1 - Batch 9/937
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 2825 : d_loss_real: 0.357332557, d_loss_fake: 0.407832474, dcg_loss: 2.034551144 - in Epoch 4/1 - Batch 14/937
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 92ms/step
# === Iter: 2830 : d_loss_real: 0.633340836, d_loss_fake: 0.391755760, dcg_loss: 2.374503136 - in Epoch 4/1 - Batch 19/937
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 117ms/step
# === Iter: 2835 : d_loss_real: 0.416883707, d_loss_fake: 0.383294940, dcg_loss: 2.375493526 - in Epoch 4/1 - Batch 24/937
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 142ms/step
# === Iter: 2840 : d_loss_real: 0.315332413, d_loss_fake: 0.326379657, dcg_loss: 2.107880354 - in Epoch 4/1 - Batch 29/937
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 2845 : d_loss_real: 0.394735456, d_loss_fake: 0.289138556, dcg_loss: 2.313319206 - in Epoch 4/1 - Batch 34/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 2850 : d_loss_real: 0.323452413, d_loss_fake: 0.430252314, dcg_loss: 2.684132814 - in Epoch 4/1 - Batch 39/937
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 2855 : d_loss_real: 0.307005703, d_loss_fake: 0.327740192, dcg_loss: 2.585472584 - in Epoch 4/1 - Batch 44/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 2860 : d_loss_real: 0.428651929, d_loss_fake: 0.402449131, dcg_loss: 2.152081013 - in Epoch 4/1 - Batch 49/937
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 2865 : d_loss_real: 0.593023837, d_loss_fake: 0.364863157, dcg_loss: 1.714978933 - in Epoch 4/1 - Batch 54/937
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 2870 : d_loss_real: 0.393356591, d_loss_fake: 0.367579699, dcg_loss: 2.300589085 - in Epoch 4/1 - Batch 59/937
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 2875 : d_loss_real: 0.565475285, d_loss_fake: 0.423558563, dcg_loss: 1.559883237 - in Epoch 4/1 - Batch 64/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 2880 : d_loss_real: 0.529156566, d_loss_fake: 0.192129344, dcg_loss: 2.606400013 - in Epoch 4/1 - Batch 69/937
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 2885 : d_loss_real: 0.349024475, d_loss_fake: 0.354438514, dcg_loss: 2.100751638 - in Epoch 4/1 - Batch 74/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 2890 : d_loss_real: 0.372800738, d_loss_fake: 0.294927478, dcg_loss: 1.936084986 - in Epoch 4/1 - Batch 79/937
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 2895 : d_loss_real: 0.475384831, d_loss_fake: 0.260601074, dcg_loss: 2.832754135 - in Epoch 4/1 - Batch 84/937
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 2900 : d_loss_real: 0.243123233, d_loss_fake: 0.346914351, dcg_loss: 2.261394978 - in Epoch 4/1 - Batch 89/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 55ms/step
# === Iter: 2905 : d_loss_real: 0.317787409, d_loss_fake: 0.459641993, dcg_loss: 1.929789305 - in Epoch 4/1 - Batch 94/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 2910 : d_loss_real: 0.483052164, d_loss_fake: 0.287717581, dcg_loss: 2.337930202 - in Epoch 4/1 - Batch 99/937
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 2915 : d_loss_real: 0.468181551, d_loss_fake: 0.270147651, dcg_loss: 2.518400669 - in Epoch 4/1 - Batch 104/937
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 2920 : d_loss_real: 0.321899980, d_loss_fake: 0.454365075, dcg_loss: 2.134449005 - in Epoch 4/1 - Batch 109/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 2925 : d_loss_real: 0.377629340, d_loss_fake: 0.475286245, dcg_loss: 1.836546898 - in Epoch 4/1 - Batch 114/937
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 2930 : d_loss_real: 0.319067687, d_loss_fake: 0.482187182, dcg_loss: 2.023413181 - in Epoch 4/1 - Batch 119/937
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 2935 : d_loss_real: 0.427741408, d_loss_fake: 0.283877254, dcg_loss: 2.707624912 - in Epoch 4/1 - Batch 124/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 2940 : d_loss_real: 0.402077138, d_loss_fake: 0.285668492, dcg_loss: 2.259983540 - in Epoch 4/1 - Batch 129/937
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 2945 : d_loss_real: 0.403530657, d_loss_fake: 0.368905813, dcg_loss: 2.245228529 - in Epoch 4/1 - Batch 134/937
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 67ms/step
# === Iter: 2950 : d_loss_real: 0.429843694, d_loss_fake: 0.312195808, dcg_loss: 2.502061129 - in Epoch 4/1 - Batch 139/937
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 2955 : d_loss_real: 0.349356145, d_loss_fake: 0.435112774, dcg_loss: 2.038062811 - in Epoch 4/1 - Batch 144/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 254ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 123ms/step
# === Iter: 2960 : d_loss_real: 0.594482780, d_loss_fake: 0.494722039, dcg_loss: 2.427728653 - in Epoch 4/1 - Batch 149/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 2965 : d_loss_real: 0.603102565, d_loss_fake: 0.324416459, dcg_loss: 1.855598807 - in Epoch 4/1 - Batch 154/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 2970 : d_loss_real: 0.327971160, d_loss_fake: 0.405118525, dcg_loss: 1.980565429 - in Epoch 4/1 - Batch 159/937
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 2975 : d_loss_real: 0.506238222, d_loss_fake: 0.333247483, dcg_loss: 2.257084846 - in Epoch 4/1 - Batch 164/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 2980 : d_loss_real: 0.343177050, d_loss_fake: 0.454040945, dcg_loss: 2.219839811 - in Epoch 4/1 - Batch 169/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 2985 : d_loss_real: 0.471521407, d_loss_fake: 0.374349266, dcg_loss: 2.290607452 - in Epoch 4/1 - Batch 174/937
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 2990 : d_loss_real: 0.408757985, d_loss_fake: 0.493225336, dcg_loss: 2.347143173 - in Epoch 4/1 - Batch 179/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 66ms/step
# === Iter: 2995 : d_loss_real: 0.385797560, d_loss_fake: 0.342158377, dcg_loss: 1.891081452 - in Epoch 4/1 - Batch 184/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 62ms/step
# === Iter: 3000 : d_loss_real: 0.387105465, d_loss_fake: 0.331339687, dcg_loss: 2.232650042 - in Epoch 4/1 - Batch 189/937
# 1/1 [==============================] - 0s 70ms/step
# *** time now:  2023-05-15 07:01:52.334543
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3005 : d_loss_real: 0.384778768, d_loss_fake: 0.435917675, dcg_loss: 2.002420902 - in Epoch 4/1 - Batch 194/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3010 : d_loss_real: 0.398271918, d_loss_fake: 0.304734468, dcg_loss: 2.016957521 - in Epoch 4/1 - Batch 199/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 69ms/step
# === Iter: 3015 : d_loss_real: 0.440312237, d_loss_fake: 0.363728821, dcg_loss: 1.721218348 - in Epoch 4/1 - Batch 204/937
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 63ms/step
# === Iter: 3020 : d_loss_real: 0.464026034, d_loss_fake: 0.302929640, dcg_loss: 2.189587593 - in Epoch 4/1 - Batch 209/937
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3025 : d_loss_real: 0.528916836, d_loss_fake: 0.463483810, dcg_loss: 1.883365393 - in Epoch 4/1 - Batch 214/937
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3030 : d_loss_real: 0.440857887, d_loss_fake: 0.314159095, dcg_loss: 2.255750895 - in Epoch 4/1 - Batch 219/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3035 : d_loss_real: 0.400330365, d_loss_fake: 0.383236796, dcg_loss: 1.966422915 - in Epoch 4/1 - Batch 224/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3040 : d_loss_real: 0.308680832, d_loss_fake: 0.475508124, dcg_loss: 1.976135492 - in Epoch 4/1 - Batch 229/937
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3045 : d_loss_real: 0.419644326, d_loss_fake: 0.364529729, dcg_loss: 1.866834402 - in Epoch 4/1 - Batch 234/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3050 : d_loss_real: 0.469903290, d_loss_fake: 0.416485816, dcg_loss: 2.081886292 - in Epoch 4/1 - Batch 239/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3055 : d_loss_real: 0.382661998, d_loss_fake: 0.464180231, dcg_loss: 1.992776036 - in Epoch 4/1 - Batch 244/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 66ms/step
# === Iter: 3060 : d_loss_real: 0.539449930, d_loss_fake: 0.483189225, dcg_loss: 2.094754696 - in Epoch 4/1 - Batch 249/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 3065 : d_loss_real: 0.360523432, d_loss_fake: 0.425606728, dcg_loss: 1.754389524 - in Epoch 4/1 - Batch 254/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3070 : d_loss_real: 0.532626927, d_loss_fake: 0.314856350, dcg_loss: 2.233587742 - in Epoch 4/1 - Batch 259/937
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3075 : d_loss_real: 0.450440496, d_loss_fake: 0.289503396, dcg_loss: 2.318375587 - in Epoch 4/1 - Batch 264/937
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 3080 : d_loss_real: 0.426079065, d_loss_fake: 0.345963150, dcg_loss: 2.488355160 - in Epoch 4/1 - Batch 269/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3085 : d_loss_real: 0.446029603, d_loss_fake: 0.378808498, dcg_loss: 2.420039415 - in Epoch 4/1 - Batch 274/937
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3090 : d_loss_real: 0.424200118, d_loss_fake: 0.255465269, dcg_loss: 2.087177992 - in Epoch 4/1 - Batch 279/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3095 : d_loss_real: 0.376928627, d_loss_fake: 0.427102715, dcg_loss: 1.907455206 - in Epoch 4/1 - Batch 284/937
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 88ms/step
# === Iter: 3100 : d_loss_real: 0.578086734, d_loss_fake: 0.280166090, dcg_loss: 2.175071716 - in Epoch 4/1 - Batch 289/937
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3105 : d_loss_real: 0.298883617, d_loss_fake: 0.419106364, dcg_loss: 2.359934807 - in Epoch 4/1 - Batch 294/937
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3110 : d_loss_real: 0.188747048, d_loss_fake: 0.362726688, dcg_loss: 2.539208412 - in Epoch 4/1 - Batch 299/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 107ms/step
# === Iter: 3115 : d_loss_real: 0.394576252, d_loss_fake: 0.249293178, dcg_loss: 2.136649132 - in Epoch 4/1 - Batch 304/937
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3120 : d_loss_real: 0.293042749, d_loss_fake: 0.527572930, dcg_loss: 1.816918135 - in Epoch 4/1 - Batch 309/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3125 : d_loss_real: 0.567172945, d_loss_fake: 0.310012817, dcg_loss: 1.801282644 - in Epoch 4/1 - Batch 314/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 62ms/step
# === Iter: 3130 : d_loss_real: 0.514629960, d_loss_fake: 0.338495672, dcg_loss: 2.289289951 - in Epoch 4/1 - Batch 319/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3135 : d_loss_real: 0.465031326, d_loss_fake: 0.292768478, dcg_loss: 2.018279552 - in Epoch 4/1 - Batch 324/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3140 : d_loss_real: 0.325420707, d_loss_fake: 0.304283410, dcg_loss: 2.025303364 - in Epoch 4/1 - Batch 329/937
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3145 : d_loss_real: 0.407127440, d_loss_fake: 0.454374075, dcg_loss: 2.407320976 - in Epoch 4/1 - Batch 334/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 55ms/step
# === Iter: 3150 : d_loss_real: 0.321383297, d_loss_fake: 0.247174054, dcg_loss: 2.151585817 - in Epoch 4/1 - Batch 339/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# === Iter: 3155 : d_loss_real: 0.374351084, d_loss_fake: 0.312385678, dcg_loss: 2.016849518 - in Epoch 4/1 - Batch 344/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 3160 : d_loss_real: 0.423572540, d_loss_fake: 0.296554923, dcg_loss: 2.119423389 - in Epoch 4/1 - Batch 349/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 69ms/step
# === Iter: 3165 : d_loss_real: 0.395984054, d_loss_fake: 0.350220174, dcg_loss: 2.453312874 - in Epoch 4/1 - Batch 354/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3170 : d_loss_real: 0.489048749, d_loss_fake: 0.445206940, dcg_loss: 2.183292389 - in Epoch 4/1 - Batch 359/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3175 : d_loss_real: 0.438841075, d_loss_fake: 0.558988690, dcg_loss: 1.848809838 - in Epoch 4/1 - Batch 364/937
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3180 : d_loss_real: 0.549619377, d_loss_fake: 0.376978517, dcg_loss: 2.365347385 - in Epoch 4/1 - Batch 369/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3185 : d_loss_real: 0.159492254, d_loss_fake: 0.458305955, dcg_loss: 2.382141352 - in Epoch 4/1 - Batch 374/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3190 : d_loss_real: 0.487598687, d_loss_fake: 0.325460672, dcg_loss: 2.306655407 - in Epoch 4/1 - Batch 379/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 3195 : d_loss_real: 0.547330856, d_loss_fake: 0.327233225, dcg_loss: 2.345230103 - in Epoch 4/1 - Batch 384/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 65ms/step
# === Iter: 3200 : d_loss_real: 0.530506790, d_loss_fake: 0.295742452, dcg_loss: 2.349012613 - in Epoch 4/1 - Batch 389/937
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 66ms/step
# === Iter: 3205 : d_loss_real: 0.348729014, d_loss_fake: 0.301803768, dcg_loss: 2.558852434 - in Epoch 4/1 - Batch 394/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3210 : d_loss_real: 0.405296415, d_loss_fake: 0.445165008, dcg_loss: 2.036718607 - in Epoch 4/1 - Batch 399/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3215 : d_loss_real: 0.562124848, d_loss_fake: 0.403823674, dcg_loss: 2.294916630 - in Epoch 4/1 - Batch 404/937
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3220 : d_loss_real: 0.323177427, d_loss_fake: 0.461250842, dcg_loss: 2.140639782 - in Epoch 4/1 - Batch 409/937
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3225 : d_loss_real: 0.362091601, d_loss_fake: 0.294472158, dcg_loss: 2.340623140 - in Epoch 4/1 - Batch 414/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 94ms/step
# === Iter: 3230 : d_loss_real: 0.291935593, d_loss_fake: 0.513337135, dcg_loss: 2.210402012 - in Epoch 4/1 - Batch 419/937
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 63ms/step
# === Iter: 3235 : d_loss_real: 0.457050830, d_loss_fake: 0.312535733, dcg_loss: 2.188817024 - in Epoch 4/1 - Batch 424/937
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 65ms/step
# === Iter: 3240 : d_loss_real: 0.277843237, d_loss_fake: 0.559118867, dcg_loss: 2.289632559 - in Epoch 4/1 - Batch 429/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 101ms/step
# === Iter: 3245 : d_loss_real: 0.442066580, d_loss_fake: 0.290565878, dcg_loss: 2.292085648 - in Epoch 4/1 - Batch 434/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3250 : d_loss_real: 0.493918419, d_loss_fake: 0.323965490, dcg_loss: 2.062216759 - in Epoch 4/1 - Batch 439/937
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 62ms/step
# === Iter: 3255 : d_loss_real: 0.411428571, d_loss_fake: 0.413200915, dcg_loss: 2.464863539 - in Epoch 4/1 - Batch 444/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 90ms/step
# === Iter: 3260 : d_loss_real: 0.338497549, d_loss_fake: 0.480470777, dcg_loss: 1.851285219 - in Epoch 4/1 - Batch 449/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 64ms/step
# === Iter: 3265 : d_loss_real: 0.430433631, d_loss_fake: 0.348926961, dcg_loss: 2.462875366 - in Epoch 4/1 - Batch 454/937
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 67ms/step
# === Iter: 3270 : d_loss_real: 0.382530063, d_loss_fake: 0.551328003, dcg_loss: 2.143565655 - in Epoch 4/1 - Batch 459/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3275 : d_loss_real: 0.500391424, d_loss_fake: 0.308618844, dcg_loss: 2.358905792 - in Epoch 4/1 - Batch 464/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3280 : d_loss_real: 0.273860246, d_loss_fake: 0.309205234, dcg_loss: 2.169443130 - in Epoch 4/1 - Batch 469/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3285 : d_loss_real: 0.414791048, d_loss_fake: 0.327798843, dcg_loss: 2.394000769 - in Epoch 4/1 - Batch 474/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3290 : d_loss_real: 0.385368079, d_loss_fake: 0.567158461, dcg_loss: 2.491921186 - in Epoch 4/1 - Batch 479/937
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 63ms/step
# === Iter: 3295 : d_loss_real: 0.382437080, d_loss_fake: 0.276747197, dcg_loss: 2.549770355 - in Epoch 4/1 - Batch 484/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3300 : d_loss_real: 0.319802940, d_loss_fake: 0.467628151, dcg_loss: 2.548531532 - in Epoch 4/1 - Batch 489/937
# 1/1 [==============================] - 0s 30ms/step
# *** time now:  2023-05-15 07:05:56.020284
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3305 : d_loss_real: 0.375179589, d_loss_fake: 0.408689797, dcg_loss: 1.836812735 - in Epoch 4/1 - Batch 494/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 68ms/step
# === Iter: 3310 : d_loss_real: 0.547221720, d_loss_fake: 0.350864142, dcg_loss: 2.003059626 - in Epoch 4/1 - Batch 499/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3315 : d_loss_real: 0.391213834, d_loss_fake: 0.379425168, dcg_loss: 1.973034620 - in Epoch 4/1 - Batch 504/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3320 : d_loss_real: 0.354065984, d_loss_fake: 0.403302491, dcg_loss: 2.213456154 - in Epoch 4/1 - Batch 509/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3325 : d_loss_real: 0.300427377, d_loss_fake: 0.318762362, dcg_loss: 2.533827782 - in Epoch 4/1 - Batch 514/937
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3330 : d_loss_real: 0.368054509, d_loss_fake: 0.456463933, dcg_loss: 2.155816793 - in Epoch 4/1 - Batch 519/937
# 2/2 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3335 : d_loss_real: 0.340850294, d_loss_fake: 0.285366654, dcg_loss: 2.011955261 - in Epoch 4/1 - Batch 524/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3340 : d_loss_real: 0.469103217, d_loss_fake: 0.485898197, dcg_loss: 3.023127794 - in Epoch 4/1 - Batch 529/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3345 : d_loss_real: 0.543379247, d_loss_fake: 0.350243986, dcg_loss: 2.449595928 - in Epoch 4/1 - Batch 534/937
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 64ms/step
# === Iter: 3350 : d_loss_real: 0.437560201, d_loss_fake: 0.265771151, dcg_loss: 2.344665527 - in Epoch 4/1 - Batch 539/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 3355 : d_loss_real: 0.420785218, d_loss_fake: 0.619057715, dcg_loss: 2.141319275 - in Epoch 4/1 - Batch 544/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 89ms/step
# === Iter: 3360 : d_loss_real: 0.430225849, d_loss_fake: 0.510031343, dcg_loss: 1.767123342 - in Epoch 4/1 - Batch 549/937
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3365 : d_loss_real: 0.251072317, d_loss_fake: 0.377489626, dcg_loss: 2.274134159 - in Epoch 4/1 - Batch 554/937
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3370 : d_loss_real: 0.320872366, d_loss_fake: 0.349590063, dcg_loss: 2.010553360 - in Epoch 4/1 - Batch 559/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 107ms/step
# === Iter: 3375 : d_loss_real: 0.370006502, d_loss_fake: 0.270881712, dcg_loss: 2.511515141 - in Epoch 4/1 - Batch 564/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3380 : d_loss_real: 0.372584999, d_loss_fake: 0.418416023, dcg_loss: 2.298108101 - in Epoch 4/1 - Batch 569/937
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 71ms/step
# === Iter: 3385 : d_loss_real: 0.457655728, d_loss_fake: 0.392975837, dcg_loss: 2.891866684 - in Epoch 4/1 - Batch 574/937
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 62ms/step
# === Iter: 3390 : d_loss_real: 0.353876829, d_loss_fake: 0.295756876, dcg_loss: 2.924238682 - in Epoch 4/1 - Batch 579/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 62ms/step
# === Iter: 3395 : d_loss_real: 0.475456446, d_loss_fake: 0.482224256, dcg_loss: 2.422881603 - in Epoch 4/1 - Batch 584/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 66ms/step
# === Iter: 3400 : d_loss_real: 0.373377234, d_loss_fake: 0.512485504, dcg_loss: 2.842989922 - in Epoch 4/1 - Batch 589/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3405 : d_loss_real: 0.428771555, d_loss_fake: 0.336131662, dcg_loss: 2.405431271 - in Epoch 4/1 - Batch 594/937
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 70ms/step
# === Iter: 3410 : d_loss_real: 0.442920446, d_loss_fake: 0.457541883, dcg_loss: 2.148652077 - in Epoch 4/1 - Batch 599/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3415 : d_loss_real: 0.319005787, d_loss_fake: 0.301040828, dcg_loss: 2.194963932 - in Epoch 4/1 - Batch 604/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3420 : d_loss_real: 0.364675760, d_loss_fake: 0.430852532, dcg_loss: 2.195310593 - in Epoch 4/1 - Batch 609/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3425 : d_loss_real: 0.344579428, d_loss_fake: 0.250803828, dcg_loss: 1.884297609 - in Epoch 4/1 - Batch 614/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 64ms/step
# === Iter: 3430 : d_loss_real: 0.361891806, d_loss_fake: 0.329736233, dcg_loss: 2.463823795 - in Epoch 4/1 - Batch 619/937
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 62ms/step
# === Iter: 3435 : d_loss_real: 0.373944402, d_loss_fake: 0.286203682, dcg_loss: 2.649301529 - in Epoch 4/1 - Batch 624/937
# ...
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 65ms/step
# === Iter: 3545 : d_loss_real: 0.546587944, d_loss_fake: 0.459442437, dcg_loss: 1.895551801 - in Epoch 4/1 - Batch 734/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3550 : d_loss_real: 0.551449180, d_loss_fake: 0.322469294, dcg_loss: 2.135328770 - in Epoch 4/1 - Batch 739/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3555 : d_loss_real: 0.298436016, d_loss_fake: 0.250255615, dcg_loss: 2.507422924 - in Epoch 4/1 - Batch 744/937
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3560 : d_loss_real: 0.391006410, d_loss_fake: 0.455581009, dcg_loss: 2.157665968 - in Epoch 4/1 - Batch 749/937
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3565 : d_loss_real: 0.284986824, d_loss_fake: 0.483251184, dcg_loss: 2.012327671 - in Epoch 4/1 - Batch 754/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3570 : d_loss_real: 0.516808510, d_loss_fake: 0.477184951, dcg_loss: 2.070298195 - in Epoch 4/1 - Batch 759/937
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 74ms/step
# === Iter: 3575 : d_loss_real: 0.373396158, d_loss_fake: 0.490816355, dcg_loss: 1.784186602 - in Epoch 4/1 - Batch 764/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3580 : d_loss_real: 0.438578010, d_loss_fake: 0.362234145, dcg_loss: 2.211490870 - in Epoch 4/1 - Batch 769/937
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3585 : d_loss_real: 0.504938304, d_loss_fake: 0.352917969, dcg_loss: 2.249621153 - in Epoch 4/1 - Batch 774/937
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 63ms/step
# === Iter: 3590 : d_loss_real: 0.402128816, d_loss_fake: 0.357558727, dcg_loss: 2.436483383 - in Epoch 4/1 - Batch 779/937
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3595 : d_loss_real: 0.559134007, d_loss_fake: 0.400497794, dcg_loss: 1.885614395 - in Epoch 4/1 - Batch 784/937
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3600 : d_loss_real: 0.469902992, d_loss_fake: 0.206335992, dcg_loss: 2.568605900 - in Epoch 4/1 - Batch 789/937
# 1/1 [==============================] - 0s 30ms/step
# *** time now:  2023-05-15 07:09:59.201880
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 68ms/step
# === Iter: 3605 : d_loss_real: 0.621080041, d_loss_fake: 0.429962367, dcg_loss: 2.245092392 - in Epoch 4/1 - Batch 794/937
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3610 : d_loss_real: 0.575555265, d_loss_fake: 0.450984120, dcg_loss: 1.809376955 - in Epoch 4/1 - Batch 799/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 3615 : d_loss_real: 0.536106467, d_loss_fake: 0.272436798, dcg_loss: 1.996418238 - in Epoch 4/1 - Batch 804/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 71ms/step
# === Iter: 3620 : d_loss_real: 0.394476533, d_loss_fake: 0.320463896, dcg_loss: 2.363348484 - in Epoch 4/1 - Batch 809/937
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3625 : d_loss_real: 0.322476953, d_loss_fake: 0.531050920, dcg_loss: 2.037335396 - in Epoch 4/1 - Batch 814/937
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3630 : d_loss_real: 0.477287948, d_loss_fake: 0.298765302, dcg_loss: 2.482131004 - in Epoch 4/1 - Batch 819/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 100ms/step
# === Iter: 3635 : d_loss_real: 0.274919540, d_loss_fake: 0.358820021, dcg_loss: 2.365614176 - in Epoch 4/1 - Batch 824/937
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 64ms/step
# === Iter: 3640 : d_loss_real: 0.376042485, d_loss_fake: 0.509666920, dcg_loss: 2.532735348 - in Epoch 4/1 - Batch 829/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 56ms/step
# === Iter: 3645 : d_loss_real: 0.484957844, d_loss_fake: 0.408832371, dcg_loss: 2.129490614 - in Epoch 4/1 - Batch 834/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 101ms/step
# === Iter: 3650 : d_loss_real: 0.402931571, d_loss_fake: 0.463236094, dcg_loss: 2.525750160 - in Epoch 4/1 - Batch 839/937
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 62ms/step
# === Iter: 3655 : d_loss_real: 0.264130831, d_loss_fake: 0.436677814, dcg_loss: 1.788965225 - in Epoch 4/1 - Batch 844/937
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3660 : d_loss_real: 0.434199363, d_loss_fake: 0.267715812, dcg_loss: 2.450057983 - in Epoch 4/1 - Batch 849/937
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 99ms/step
# === Iter: 3665 : d_loss_real: 0.332807124, d_loss_fake: 0.501356244, dcg_loss: 2.439485550 - in Epoch 4/1 - Batch 854/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3670 : d_loss_real: 0.402188241, d_loss_fake: 0.368814409, dcg_loss: 2.857438087 - in Epoch 4/1 - Batch 859/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3675 : d_loss_real: 0.380951464, d_loss_fake: 0.277740806, dcg_loss: 3.127280474 - in Epoch 4/1 - Batch 864/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3680 : d_loss_real: 0.399125516, d_loss_fake: 0.342333853, dcg_loss: 2.627961159 - in Epoch 4/1 - Batch 869/937
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3685 : d_loss_real: 0.542219996, d_loss_fake: 0.482476890, dcg_loss: 2.474796772 - in Epoch 4/1 - Batch 874/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3690 : d_loss_real: 0.276836425, d_loss_fake: 0.412369788, dcg_loss: 2.044870377 - in Epoch 4/1 - Batch 879/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3695 : d_loss_real: 0.399922192, d_loss_fake: 0.361052543, dcg_loss: 2.083859444 - in Epoch 4/1 - Batch 884/937
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3700 : d_loss_real: 0.489367843, d_loss_fake: 0.444557667, dcg_loss: 2.584259510 - in Epoch 4/1 - Batch 889/937
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3705 : d_loss_real: 0.361093998, d_loss_fake: 0.314490676, dcg_loss: 2.167353630 - in Epoch 4/1 - Batch 894/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3710 : d_loss_real: 0.556008875, d_loss_fake: 0.452418745, dcg_loss: 2.200660706 - in Epoch 4/1 - Batch 899/937
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# === Iter: 3715 : d_loss_real: 0.362558067, d_loss_fake: 0.345756918, dcg_loss: 2.192001581 - in Epoch 4/1 - Batch 904/937
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# === Iter: 3720 : d_loss_real: 0.310879827, d_loss_fake: 0.424032420, dcg_loss: 2.025726557 - in Epoch 4/1 - Batch 909/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3725 : d_loss_real: 0.342837811, d_loss_fake: 0.321081340, dcg_loss: 2.327544212 - in Epoch 4/1 - Batch 914/937
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# === Iter: 3730 : d_loss_real: 0.373429775, d_loss_fake: 0.282845259, dcg_loss: 2.491338015 - in Epoch 4/1 - Batch 919/937
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3735 : d_loss_real: 0.327261209, d_loss_fake: 0.284932971, dcg_loss: 2.817344189 - in Epoch 4/1 - Batch 924/937
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 61ms/step
# === Iter: 3740 : d_loss_real: 0.240852445, d_loss_fake: 0.401442051, dcg_loss: 2.358851910 - in Epoch 4/1 - Batch 929/937
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 60ms/step
# === Iter: 3745 : d_loss_real: 0.295702994, d_loss_fake: 0.358008683, dcg_loss: 2.054265738 - in Epoch 4/1 - Batch 934/937
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 67ms/step
#
#
#  ~~~ DCGAN trainging ends at 2023-05-15 07:11:58.160255
